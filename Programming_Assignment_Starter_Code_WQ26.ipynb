# %% [markdown]
# # Programming Assignment 3
#
# **Colab Free Tier has pretty strict GPU usage time limits**
#
# **I would HIGHLY recommend doing all development on the CPU runtime instance (you can change this by clicking the dropdown arrow next to Connect (top right) --> Change Runtime Type --> CPU or T4), and then only switching to the T4 runtime (T4 is an Nvidia GPU), when you are ready to actually train the model**

# %% [markdown]
# ## 1. Setup
#
# Installing packages and downloading Atari environments

# %%
pip install ale-py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ale-py in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (0.11.2)
# Requirement already satisfied: importlib-metadata>=4.10.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from ale-py) (8.7.0)
# Requirement already satisfied: numpy>1.20 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from ale-py) (2.0.2)
# Requirement already satisfied: typing-extensions in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from ale-py) (4.14.0)
# Requirement already satisfied: zipp>=3.20 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.10.0->ale-py) (3.23.0)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch torchvision torchaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-2.8.0-cp39-none-macosx_11_0_arm64.whl (73.6 MB)
#      |████████████████████████████████| 73.6 MB 964 kB/s eta 0:00:013
# Collecting torchvision
#   Downloading torchvision-0.23.0-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 13.9 MB/s eta 0:00:01
# Collecting torchaudio
#   Downloading torchaudio-2.8.0-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 5.6 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from torch) (4.14.0)
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 39.3 MB/s eta 0:00:01
# Requirement already satisfied: jinja2 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from torch) (3.1.6)
# Collecting networkx
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 43.3 MB/s eta 0:00:01
# Collecting fsspec
#   Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 74.9 MB/s eta 0:00:01
# Collecting filelock
#   Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from torchvision) (11.2.1)
# Requirement already satisfied: numpy in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from torchvision) (2.0.2)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      |████████████████████████████████| 536 kB 22.1 MB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from jinja2->torch) (3.0.2)
# Installing collected packages: mpmath, sympy, networkx, fsspec, filelock, torch, torchvision, torchaudio
# Successfully installed filelock-3.19.1 fsspec-2025.10.0 mpmath-1.3.0 networkx-3.2.1 sympy-1.14.0 torch-2.8.0 torchaudio-2.8.0 torchvision-0.23.0
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "gymnasium[atari,other]" ale-py "autorom[accept-rom-license]" moviepy "imageio[ffmpeg]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium[atari,other] in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (1.1.1)
# Requirement already satisfied: ale-py in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (0.11.2)
# Requirement already satisfied: autorom[accept-rom-license] in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (0.6.1)
# Requirement already satisfied: moviepy in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (2.2.1)
# Requirement already satisfied: imageio[ffmpeg] in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (2.37.2)
# Requirement already satisfied: numpy>=1.21.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from gymnasium[atari,other]) (2.0.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from gymnasium[atari,other]) (0.0.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from gymnasium[atari,other]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from gymnasium[atari,other]) (4.14.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from gymnasium[atari,other]) (8.7.0)
# Requirement already satisfied: seaborn>=0.13 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from gymnasium[atari,other]) (0.13.2)
# Requirement already satisfied: matplotlib>=3.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from gymnasium[atari,other]) (3.9.4)
# Requirement already satisfied: opencv-python>=3.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from gymnasium[atari,other]) (4.13.0.92)
# Requirement already satisfied: requests in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from autorom[accept-rom-license]) (2.32.4)
# Requirement already satisfied: click in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from autorom[accept-rom-license]) (8.1.8)
# Requirement already satisfied: AutoROM.accept-rom-license in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from autorom[accept-rom-license]) (0.6.1)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from moviepy) (5.2.1)
# Requirement already satisfied: pillow<12.0,>=9.2.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from moviepy) (11.2.1)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from moviepy) (1.2.1)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from moviepy) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from moviepy) (0.1.12)
# Requirement already satisfied: psutil in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from imageio[ffmpeg]) (7.1.0)
# Requirement already satisfied: zipp>=3.20 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.0->gymnasium[atari,other]) (3.23.0)
# Requirement already satisfied: cycler>=0.10 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gymnasium[atari,other]) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gymnasium[atari,other]) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gymnasium[atari,other]) (1.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gymnasium[atari,other]) (6.5.2)
# Requirement already satisfied: packaging>=20.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gymnasium[atari,other]) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gymnasium[atari,other]) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gymnasium[atari,other]) (4.58.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.0->gymnasium[atari,other]) (3.2.3)
# Requirement already satisfied: tqdm in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from proglog<=1.0.0->moviepy) (4.67.3)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[atari,other]) (1.15.0)
# Requirement already satisfied: pandas>=1.2 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from seaborn>=0.13->gymnasium[atari,other]) (2.3.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[atari,other]) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn>=0.13->gymnasium[atari,other]) (2025.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from requests->autorom[accept-rom-license]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from requests->autorom[accept-rom-license]) (2025.6.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from requests->autorom[accept-rom-license]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marqlott/Library/Python/3.9/lib/python/site-packages (from requests->autorom[accept-rom-license]) (3.10)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install git+https://github.com/MLivanos/colabgymrender.git
# Out:
# Collecting git+https://github.com/MLivanos/colabgymrender.git
#   Cloning https://github.com/MLivanos/colabgymrender.git to /private/var/folders/sv/0kxycdhn70x_kdsd2hrfp03c0000gn/T/pip-req-build-f2fef6m7
#   Running command git clone --filter=blob:none --quiet https://github.com/MLivanos/colabgymrender.git /private/var/folders/sv/0kxycdhn70x_kdsd2hrfp03c0000gn/T/pip-req-build-f2fef6m7
#   Resolved https://github.com/MLivanos/colabgymrender.git to commit 8526ad9deec50a445e63b8faf2b894d3b0cd7cd2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: moviepy in /opt/anaconda3/lib/python3.12/site-packages (from colabgymrender==1.1.0) (2.2.1)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from moviepy->colabgymrender==1.1.0) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from moviepy->colabgymrender==1.1.0) (2.33.1)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from moviepy->colabgymrender==1.1.0) (0.6.0)
# Requirement already satisfied: numpy>=1.25.0 in /opt/anaconda3/lib/python3.12/site-packages (from moviepy->colabgymrender==1.1.0) (1.26.4)
# Requirement already satisfied: proglog<=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from moviepy->colabgymrender==1.1.0) (0.1.12)
# Requirement already satisfied: python-dotenv>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from moviepy->colabgymrender==1.1.0) (0.21.0)
# Requirement already satisfied: pillow<12.0,>=9.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from moviepy->colabgymrender==1.1.0) (9.5.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from proglog<=1.0.0->moviepy->colabgymrender==1.1.0) (4.66.5)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Visualize

# %%
import base64
import os
from IPython.display import HTML, display

def render_mp4_video(video_folder):
    """Finds the first mp4 in the folder and displays it in the notebook."""
    video_files = [f for f in os.listdir(video_folder) if f.endswith('.mp4')]

    if not video_files:
        print("No video found! Make sure the episode actually finished and triggered the recorder.")
        return

    # Pick the most recent video
    video_path = os.path.join(video_folder, sorted(video_files)[-1])

    video_file = open(video_path, "rb").read()
    encoded = base64.b64encode(video_file).decode("ascii")

    html_code = f"""
    <video width="600" height="400" controls>
        <source src="data:video/mp4;base64,{encoded}" type="video/mp4">
    </video>
    """
    display(HTML(html_code))

# %% [markdown]
# ### Demo of environment

# %%
import gymnasium as gym
import ale_py

# 1. Setup Environment
gym.register_envs(ale_py)
env = gym.make("ALE/MsPacman-v5", render_mode="rgb_array")

# 2. Wrap for recording (recording the first episode)
video_path = "./saved-videos"
env = gym.wrappers.RecordVideo(
    env,
    video_folder=video_path,
    episode_trigger=lambda x: x == 0,
    name_prefix="pacman-run"
)

# 3. Run a quick episode
obs, info = env.reset()
done = False
while not done:
    action = env.action_space.sample() # Random actions
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

env.close()

# 4. SHOW THE VIDEO IN THE CELL
render_mp4_video(video_path)
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# /Users/marqlott/Library/Python/3.9/lib/python/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /Users/marqlott/Downloads/PA#3/saved-videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
#     <video width="600" height="400" controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %% [markdown]
# ## Deep Q-Learning

# %% [markdown]
# ### 2.1 Environment and Model Setup

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
import os
from collections import deque
import gymnasium as gym
import ale_py
import matplotlib.pyplot as plt
import time

# Gymnasium v1.0.0+ standard imports
from gymnasium.wrappers import (
    AtariPreprocessing,
    FrameStackObservation,
    TransformObservation,
    RecordVideo
)

def make_lite_env(env_id, render_mode=None, is_eval=False):
    """
    Standardized Atari Environment Factory.

    This function applies the 'Atari Preprocessing' suite which is essential
    for training stability. It reduces memory usage, simplifies the input
    space, and provides the agent with 'vision' of movement.
    """

    # 1. Registration: Ensures the ALE (Arcade Learning Environment) environments
    # are recognized by Gymnasium.
    gym.register_envs(ale_py)

    # 2. Base Env: Creates the raw environment. 'frameskip=1' is set here because
    # we handle skipping manually in the AtariPreprocessing wrapper for finer control.
    env = gym.make(env_id, render_mode=render_mode, frameskip=1)

    # 3. AtariPreprocessing: The "Workhorse" wrapper.
    # - screen_size=84: Downscales from ~210x160 to 84x84 (drastic speedup).
    # - grayscale_obs: Removes color (RGB) to reduce input channels from 3 to 1.
    # - frame_skip=4: The agent only 'sees' every 4th frame. The chosen action
    #   is repeated for the skipped frames. This speeds up training 4x.
    # - terminal_on_life_loss: CRITICAL FOR TRAINING. In many Atari games,
    #   losing a life doesn't reset the game, but we want the agent to treat
    #   it as a 'Failure' state to learn survival. During evaluation (is_eval),
    #   we set this to False to see the agent's full 3-life performance.
    env = AtariPreprocessing(
        env,
        screen_size=84,
        grayscale_obs=True,
        frame_skip=4,
        terminal_on_life_loss=not is_eval
    )

    # 4. FrameStack: Adds temporal context (Time).
    # A single grayscale frame is just a still image; the agent can't tell if
    # Pac-Man is moving left or right. By stacking the last 4 frames, the CNN
    # can see 'velocity' and 'direction' of ghosts and players.
    # Input shape becomes: (4, 84, 84)
    env = FrameStackObservation(env, stack_size=4)

    new_obs_space = gym.spaces.Box(
            low=0, high=255, shape=env.observation_space.shape, dtype=np.uint8
        )
    env = TransformObservation(
        env,
        lambda obs: np.array(obs).astype(np.uint8),
        new_obs_space
    )

    return env

# %% [markdown]
# Mount the Google Drive
#
# In case the runtime disconnected, temporary files lose.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Plot the loss and reward

# %%
def plot_metrics(rewards_history, losses, reward_window=20):
    """
    X-axis = Training Steps (matching console logs)
    Y-axis = Episode Rewards
    """
    fig, ax = plt.subplots(1, 2, figsize=(15, 5))

    if len(rewards_history) > 0:
        # 1. Convert to numpy array: col 0 is Steps, col 1 is Reward
        data = np.array(rewards_history)
        steps = data[:, 0]
        rewards = data[:, 1]

        # 2. Reward Plot
        ax[0].plot(steps, rewards, label='Episode Score', alpha=0.3, color='dodgerblue')

        # Calculate moving average
        if len(rewards) > reward_window:
            ma = np.convolve(rewards, np.ones(reward_window)/reward_window, mode='valid')
            ma_steps = steps[reward_window-1:]
            ax[0].plot(ma_steps, ma, label=f'{reward_window}-Ep Moving Avg', color='red', linewidth=2)

        ax[0].set_title("Ms. Pacman Performance")
        ax[0].set_xlabel("Total Steps")
        ax[0].set_ylabel("Reward")
        ax[0].legend()
        ax[0].grid(True, alpha=0.3)

    # 3. Loss Plot (Logged per optimization step)
    if len(losses) > 100:
        ma_loss = np.convolve(losses, np.ones(100)/100, mode='valid')
        ax[1].plot(ma_loss, color='forestgreen', label='Loss Trend')
    else:
        ax[1].plot(losses, color='forestgreen', alpha=0.5)

    ax[1].set_title("Training Loss (Internal Error)")
    ax[1].set_xlabel("Optimization Steps")
    ax[1].set_ylabel("MSE Loss")
    ax[1].set_yscale('log') # Log scale handles the huge drops in loss better
    ax[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig('training_progress.png')
    plt.show()

# %% [markdown]
# ### 2.2 Q Network

# %%
class QNetwork(nn.Module):
    def __init__(self, n_actions):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(4, 16, 8, stride=4),  # (4, 84, 84) -> (16, 20, 20)
            nn.ReLU(),
            nn.Conv2d(16, 32, 4, stride=2), # (16, 20, 20) -> (32, 9, 9)
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(32 * 9 * 9, 256),
            nn.ReLU(),
            nn.Linear(256, n_actions)
        )

    def forward(self, x):
      x = x.float() / 255.0
      return self.network(x)

# %% [markdown]
# ### 2.3 Configuaration and hyperparameters

# %%
# --- SYSTEM & ENVIRONMENT ---
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Hardware: GPU if available, else CPU
ENV_ID = "ALE/MsPacman-v5"                                           # Game: Ms. Pacman (v5 includes sticky actions)

# --- HYPERPARAMETERS ---
LR = 2.5e-4         # NOTE: CHANGED from 1e-4 to 2.5e-4
BATCH_SIZE = 32      # Minibatch: Number of transitions used per training step
GAMMA = 0.99         # Discount Factor: Importance of future vs. immediate rewards

# --- TRAINING SCALE ---
MEMORY_SIZE = 50000  # NOTE: CHANGED from 10000 to 50000
TOTAL_STEPS = 500000 # Training Duration: Total frames the agent will experience

CHECKPOINT_PATH = "pacman_dqn_checkpoint.pth" # Save File: Path for model weights
# TODO Change to Google drive path if needed. "/content/drive/My Drive/" + CHECKPOINT_PATH

history_rewards = []  # Total reward per episode/life
history_loss = []     # MSE loss per optimization step
current_episode_reward = 0

# %% [markdown]
# ### 2.4 Initialization

# %%
env = make_lite_env(ENV_ID, is_eval=False) # Change is_eval to True and the reward in the training loop to train on all three lives.
q_net = QNetwork(env.action_space.n).to(DEVICE)
target_net = QNetwork(env.action_space.n).to(DEVICE)
optimizer = optim.Adam(q_net.parameters(), lr=LR)
memory = deque(maxlen=MEMORY_SIZE)

start_step = 0
resume_from_checkpoint = True # Set to True to resume from disconnected training. You can not load any other models for training.

if resume_from_checkpoint and os.path.exists(CHECKPOINT_PATH):
    checkpoint = torch.load(CHECKPOINT_PATH, map_location=DEVICE)
    q_net.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    start_step = checkpoint['step']
    # Load history if you want to keep plots continuous
    history_rewards = checkpoint.get('history_rewards', [])
    history_loss = checkpoint.get('history_loss', [])
    print(f"Resuming from step {start_step}")

target_net.load_state_dict(q_net.state_dict())
obs, _ = env.reset()
# Out:
# Resuming from step 490000

# %% [markdown]
# ### 2.5 Training Loop

# %%
start_time = time.time()
print(f"Starting training on {DEVICE}...")
for step in range(start_step, TOTAL_STEPS):
    # NOTE: CHANGED from max(0.1, 1.0 - (step / (TOTAL_STEPS * 0.8))) to max(0.05, 1.0 - (step / (TOTAL_STEPS * 0.4)))
    epsilon = max(0.05, 1.0 - (step / (TOTAL_STEPS * 0.4)))

    if random.random() < epsilon:
        action = env.action_space.sample()
    else:
        with torch.no_grad():
            state_t = torch.FloatTensor(np.array([obs])).to(DEVICE)
            # TODO Code: Get action
            action = q_net(state_t).argmax(dim=1).item()

    next_obs, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    current_episode_reward += reward
    memory.append((obs, action, reward, next_obs, terminated))
    obs = next_obs

    if done:
        history_rewards.append([step, current_episode_reward])
        current_episode_reward = 0
        obs, _ = env.reset()

    if len(memory) > BATCH_SIZE:
        # TODO Code: Random sample a batch from reply buffer
        batch = random.sample(memory, BATCH_SIZE)

        s, a, r, ns, d = zip(*batch)
        s = torch.from_numpy(np.array(s)).to(DEVICE)
        ns = torch.from_numpy(np.array(ns)).to(DEVICE)

        a = torch.LongTensor(a).to(DEVICE).unsqueeze(1)
        r = torch.FloatTensor(r).to(DEVICE)
        d = torch.FloatTensor(d).to(DEVICE)

        # Now when you call q_net(s), the normalization happens on GPU!
        current_q = q_net(s).gather(1, a).squeeze()

        with torch.no_grad():
            next_q = target_net(ns).max(1)[0]
            # TODO Code: Get Q Value, Update of target_q
            target_q = r + (1 - d) * GAMMA * next_q

        # TODO Code: Loss function on current_q and target_q
        loss = nn.MSELoss()(current_q, target_q)
        optimizer.zero_grad()
        loss.backward()
        
        # NOTE: ADDED gradient clipping for training stability
        torch.nn.utils.clip_grad_norm_(q_net.parameters(), max_norm=10)
        # End gradient clipping addition
        
        optimizer.step()
        history_loss.append(loss.item())

    if step % 10000 == 0 and step > start_step:
        target_net.load_state_dict(q_net.state_dict())
        torch.save({
            'step': step,
            'model_state_dict': q_net.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'history_rewards': history_rewards,
            'history_loss': history_loss
        }, CHECKPOINT_PATH)

        # Extract just the rewards (column 1) from the last 20 entries
        last_rewards = [r[1] for r in history_rewards[-20:]]
        avg_reward = np.mean(last_rewards) if last_rewards else 0
        print(f"Step {step} | Eps: {epsilon:.2f} | Avg Reward (Last 20): {avg_reward:.1f}")

env.close()

# Calculate and display execution time
end_time = time.time()
total_duration = end_time - start_time
minutes = int(total_duration // 60)
seconds = int(total_duration % 60)

print(f"\nTraining Complete!")
print(f"Total Training Time: {minutes}m {seconds}s")
# Out:
# Starting training on cpu...
# Step 440000 | Eps: 0.05 | Avg Reward (Last 20): 610.0
# Step 450000 | Eps: 0.05 | Avg Reward (Last 20): 622.0
# Step 460000 | Eps: 0.05 | Avg Reward (Last 20): 769.0
# Step 470000 | Eps: 0.05 | Avg Reward (Last 20): 809.0
# Step 480000 | Eps: 0.05 | Avg Reward (Last 20): 686.5
# Step 490000 | Eps: 0.05 | Avg Reward (Last 20): 720.0
#
# Training Complete!
# Total Training Time: 48m 23s

# %% [markdown]
# ### 2.6 Training Results

# %% [markdown]
# Plot

# %%
# Call the plot function
# This uses the history collected during the loop
plot_metrics(history_rewards, history_loss)

# %% [markdown]
# Game Video

# %%
eval_env = make_lite_env(ENV_ID, render_mode="rgb_array", is_eval=True)
video_path = "./pacman_trained"
eval_env = RecordVideo(eval_env, video_folder=video_path, name_prefix="dqn-pacman", episode_trigger=lambda x: True)

obs, _ = eval_env.reset()
done = False
total_eval_score = 0  # <--- NEW: Score tracker

while not done:
    with torch.no_grad():
        state_t = torch.FloatTensor(np.array([obs])).to(DEVICE)
        action = q_net(state_t).argmax().item()

    obs, reward, terminated, truncated, _ = eval_env.step(action)
    total_eval_score += reward  # <--- Accumulate score
    done = terminated or truncated

print(f"--- Evaluation Complete ---")
print(f"Final Game Score: {total_eval_score}") # <--- Print the result
eval_env.close()

render_mp4_video(video_path)
# Out:
# --- Evaluation Complete ---
# Final Game Score: 1320.0
#     <video width="600" height="400" controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %% [markdown]
# ### 2.7 Save the model if needed

# %%
# --- After the training loop finishes ---

final_model_path = "pacman_final_dqn.pth" # Change to Google Drive path if needed

# 1. Save the model weights and training metadata
save_data = {
    'model_state_dict': q_net.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'total_steps': TOTAL_STEPS,
    'epsilon_final': epsilon,
    'env_id': ENV_ID
}

torch.save(save_data, final_model_path)
print(f"\n✅ Final model saved to {final_model_path}")
# Out:
# ✅ Final model saved to pacman_final_dqn.pth

# %% [markdown]
# ## 3. Bonus Points Algorithm

# %% [markdown]
# Game score should be higher than 1500 to be eligible for bonus points.

# %%
BONUS_ENV_ID = ENV_ID
BONUS_TOTAL_STEPS = 2_500_000 
BONUS_MEMORY_SIZE = 200_000
BONUS_BATCH_SIZE = 32
BONUS_GAMMA = 0.995
BONUS_LR_START = 3e-4
BONUS_LR_END = 5e-6
BONUS_EPS_MIN = 0.02
BONUS_EPS_DECAY_FRACTION = 0.6
BONUS_TARGET_SYNC = 5_000
BONUS_CHECKPOINT_PATH = "pacman_bonus_checkpoint.pth"
BONUS_BEST_PATH = "pacman_bonus_best.pth"

# Resume is ONLY for interrupted sessions of this same bonus run. 
BONUS_RESUME_FROM_CHECKPOINT = True

bonus_env = make_lite_env(BONUS_ENV_ID, is_eval=False)
bonus_q_net = QNetwork(bonus_env.action_space.n).to(DEVICE)
bonus_target_net = QNetwork(bonus_env.action_space.n).to(DEVICE)
bonus_target_net.load_state_dict(bonus_q_net.state_dict())
bonus_optimizer = optim.Adam(bonus_q_net.parameters(), lr=BONUS_LR_START)
bonus_memory = deque(maxlen=BONUS_MEMORY_SIZE)

bonus_history_rewards = []
bonus_history_loss = []
bonus_episode_reward = 0
bonus_best_avg_reward = -float("inf")
bonus_start_step = 0

if BONUS_RESUME_FROM_CHECKPOINT and os.path.exists(BONUS_CHECKPOINT_PATH):
    bonus_checkpoint = torch.load(BONUS_CHECKPOINT_PATH, map_location=DEVICE)
    bonus_q_net.load_state_dict(bonus_checkpoint["model_state_dict"])
    bonus_target_net.load_state_dict(bonus_q_net.state_dict())
    bonus_optimizer.load_state_dict(bonus_checkpoint["optimizer_state_dict"])
    bonus_start_step = bonus_checkpoint.get("step", 0)
    bonus_history_rewards = bonus_checkpoint.get("history_rewards", [])
    bonus_history_loss = bonus_checkpoint.get("history_loss", [])
    bonus_best_avg_reward = bonus_checkpoint.get("best_avg_reward", -float("inf"))
    print(f"[BONUS] Resuming interrupted bonus run from step {bonus_start_step}")

bonus_obs, _ = bonus_env.reset()
bonus_start_time = time.time()
step = bonus_start_step

print(f"Starting BONUS training on {DEVICE} for up to {BONUS_TOTAL_STEPS} steps...")

try:
    for step in range(bonus_start_step, BONUS_TOTAL_STEPS):
        epsilon = max(BONUS_EPS_MIN, 1.0 - (step / (BONUS_TOTAL_STEPS * BONUS_EPS_DECAY_FRACTION)))

        # Linear LR decay for stability late in training
        lr = BONUS_LR_END + (BONUS_LR_START - BONUS_LR_END) * max(
            0.0, 1.0 - (step / (BONUS_TOTAL_STEPS * 0.8))
        )
        for param_group in bonus_optimizer.param_groups:
            param_group["lr"] = lr

        if random.random() < epsilon:
            action = bonus_env.action_space.sample()
        else:
            with torch.no_grad():
                state_t = torch.FloatTensor(np.array([bonus_obs])).to(DEVICE)
                action = bonus_q_net(state_t).argmax(dim=1).item()

        next_obs, reward, terminated, truncated, _ = bonus_env.step(action)
        done = terminated or truncated
        bonus_episode_reward += reward

        bonus_memory.append((bonus_obs, action, reward, next_obs, terminated))
        bonus_obs = next_obs

        if done:
            bonus_history_rewards.append([step, bonus_episode_reward])
            bonus_episode_reward = 0
            bonus_obs, _ = bonus_env.reset()

        if len(bonus_memory) > BONUS_BATCH_SIZE:
            batch = random.sample(bonus_memory, BONUS_BATCH_SIZE)
            s, a, r, ns, d = zip(*batch)

            s = torch.from_numpy(np.array(s)).to(DEVICE)
            ns = torch.from_numpy(np.array(ns)).to(DEVICE)
            a = torch.LongTensor(a).to(DEVICE).unsqueeze(1)
            r = torch.FloatTensor(r).to(DEVICE)
            d = torch.FloatTensor(d).to(DEVICE)

            current_q = bonus_q_net(s).gather(1, a).squeeze()

            with torch.no_grad():
                # Double DQN target: action from online net, value from target net
                next_actions = bonus_q_net(ns).argmax(dim=1, keepdim=True)
                next_q = bonus_target_net(ns).gather(1, next_actions).squeeze(1)
                target_q = r + (1 - d) * BONUS_GAMMA * next_q

            loss = nn.SmoothL1Loss()(current_q, target_q)
            bonus_optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(bonus_q_net.parameters(), max_norm=10)
            bonus_optimizer.step()
            bonus_history_loss.append(loss.item())

        if step % BONUS_TARGET_SYNC == 0 and step > 0:
            bonus_target_net.load_state_dict(bonus_q_net.state_dict())

        if step % 10_000 == 0 and step > 0:
            last_rewards = [x[1] for x in bonus_history_rewards[-20:]]
            avg_reward = np.mean(last_rewards) if last_rewards else 0.0
            print(f"[BONUS] Step {step} | Eps: {epsilon:.2f} | LR: {lr:.6f} | Avg Reward (Last 20): {avg_reward:.1f}")

            torch.save(
                {
                    "step": step,
                    "model_state_dict": bonus_q_net.state_dict(),
                    "optimizer_state_dict": bonus_optimizer.state_dict(),
                    "history_rewards": bonus_history_rewards,
                    "history_loss": bonus_history_loss,
                    "best_avg_reward": bonus_best_avg_reward,
                },
                BONUS_CHECKPOINT_PATH,
            )

            if avg_reward > bonus_best_avg_reward:
                bonus_best_avg_reward = avg_reward
                torch.save(
                    {
                        "step": step,
                        "avg_reward": avg_reward,
                        "model_state_dict": bonus_q_net.state_dict(),
                    },
                    BONUS_BEST_PATH,
                )
                print(f"[BONUS] New best checkpoint saved at step {step} with avg reward {avg_reward:.1f}")

except KeyboardInterrupt:
    print("[BONUS] Training interrupted by user.")

finally:
    bonus_env.close()
    torch.save(
        {
            "step": step,
            "model_state_dict": bonus_q_net.state_dict(),
            "optimizer_state_dict": bonus_optimizer.state_dict(),
            "history_rewards": bonus_history_rewards,
            "history_loss": bonus_history_loss,
            "best_avg_reward": bonus_best_avg_reward,
        },
        BONUS_CHECKPOINT_PATH,
    )

bonus_end_time = time.time()
bonus_minutes = int((bonus_end_time - bonus_start_time) // 60)
bonus_seconds = int((bonus_end_time - bonus_start_time) % 60)
print(f"[BONUS] Training complete. Time: {bonus_minutes}m {bonus_seconds}s")
print(f"[BONUS] Latest checkpoint: {BONUS_CHECKPOINT_PATH}")
print(f"[BONUS] Best checkpoint:   {BONUS_BEST_PATH}")
# Out:
# [BONUS] Resuming interrupted bonus run from step 5606
# Starting BONUS training on cpu for up to 2500000 steps...
# [BONUS] Step 10000 | Eps: 0.99 | LR: 0.000299 | Avg Reward (Last 20): 101.0
# [BONUS] New best checkpoint saved at step 10000 with avg reward 101.0
# [BONUS] Step 20000 | Eps: 0.99 | LR: 0.000297 | Avg Reward (Last 20): 101.0
# [BONUS] Step 30000 | Eps: 0.98 | LR: 0.000296 | Avg Reward (Last 20): 108.0
# [BONUS] New best checkpoint saved at step 30000 with avg reward 108.0
# [BONUS] Step 40000 | Eps: 0.97 | LR: 0.000294 | Avg Reward (Last 20): 113.5
# [BONUS] New best checkpoint saved at step 40000 with avg reward 113.5
# [BONUS] Step 50000 | Eps: 0.97 | LR: 0.000293 | Avg Reward (Last 20): 98.5
# [BONUS] Step 60000 | Eps: 0.96 | LR: 0.000291 | Avg Reward (Last 20): 117.5
# [BONUS] New best checkpoint saved at step 60000 with avg reward 117.5
# [BONUS] Step 70000 | Eps: 0.95 | LR: 0.000290 | Avg Reward (Last 20): 99.0
# [BONUS] Step 80000 | Eps: 0.95 | LR: 0.000288 | Avg Reward (Last 20): 101.5
# [BONUS] Step 90000 | Eps: 0.94 | LR: 0.000287 | Avg Reward (Last 20): 114.5
# [BONUS] Step 100000 | Eps: 0.93 | LR: 0.000285 | Avg Reward (Last 20): 112.5
# [BONUS] Step 110000 | Eps: 0.93 | LR: 0.000284 | Avg Reward (Last 20): 108.0
# [BONUS] Step 120000 | Eps: 0.92 | LR: 0.000282 | Avg Reward (Last 20): 115.0
# [BONUS] Step 130000 | Eps: 0.91 | LR: 0.000281 | Avg Reward (Last 20): 100.0
# [BONUS] Step 140000 | Eps: 0.91 | LR: 0.000279 | Avg Reward (Last 20): 110.5
# [BONUS] Step 150000 | Eps: 0.90 | LR: 0.000278 | Avg Reward (Last 20): 144.5
# [BONUS] New best checkpoint saved at step 150000 with avg reward 144.5
# [BONUS] Step 160000 | Eps: 0.89 | LR: 0.000276 | Avg Reward (Last 20): 134.0
# [BONUS] Step 170000 | Eps: 0.89 | LR: 0.000275 | Avg Reward (Last 20): 124.5
# [BONUS] Step 180000 | Eps: 0.88 | LR: 0.000273 | Avg Reward (Last 20): 117.5
# [BONUS] Step 190000 | Eps: 0.87 | LR: 0.000272 | Avg Reward (Last 20): 124.5
# [BONUS] Step 200000 | Eps: 0.87 | LR: 0.000270 | Avg Reward (Last 20): 108.0
# [BONUS] Step 210000 | Eps: 0.86 | LR: 0.000269 | Avg Reward (Last 20): 120.0
# [BONUS] Step 220000 | Eps: 0.85 | LR: 0.000268 | Avg Reward (Last 20): 107.0
# [BONUS] Step 230000 | Eps: 0.85 | LR: 0.000266 | Avg Reward (Last 20): 145.5
# [BONUS] New best checkpoint saved at step 230000 with avg reward 145.5
# [BONUS] Step 240000 | Eps: 0.84 | LR: 0.000265 | Avg Reward (Last 20): 126.5
# [BONUS] Step 250000 | Eps: 0.83 | LR: 0.000263 | Avg Reward (Last 20): 155.0
# [BONUS] New best checkpoint saved at step 250000 with avg reward 155.0
# [BONUS] Step 260000 | Eps: 0.83 | LR: 0.000262 | Avg Reward (Last 20): 160.5
# [BONUS] New best checkpoint saved at step 260000 with avg reward 160.5
# [BONUS] Step 270000 | Eps: 0.82 | LR: 0.000260 | Avg Reward (Last 20): 154.0
# [BONUS] Step 280000 | Eps: 0.81 | LR: 0.000259 | Avg Reward (Last 20): 146.0
# [BONUS] Step 290000 | Eps: 0.81 | LR: 0.000257 | Avg Reward (Last 20): 131.0
# [BONUS] Step 300000 | Eps: 0.80 | LR: 0.000256 | Avg Reward (Last 20): 136.5
# [BONUS] Step 310000 | Eps: 0.79 | LR: 0.000254 | Avg Reward (Last 20): 156.5
# [BONUS] Step 320000 | Eps: 0.79 | LR: 0.000253 | Avg Reward (Last 20): 169.0
# [BONUS] New best checkpoint saved at step 320000 with avg reward 169.0
# [BONUS] Step 330000 | Eps: 0.78 | LR: 0.000251 | Avg Reward (Last 20): 147.0
# [BONUS] Step 340000 | Eps: 0.77 | LR: 0.000250 | Avg Reward (Last 20): 171.0
# [BONUS] New best checkpoint saved at step 340000 with avg reward 171.0
# [BONUS] Step 350000 | Eps: 0.77 | LR: 0.000248 | Avg Reward (Last 20): 182.0
# [BONUS] New best checkpoint saved at step 350000 with avg reward 182.0
# [BONUS] Step 360000 | Eps: 0.76 | LR: 0.000247 | Avg Reward (Last 20): 222.5
# [BONUS] New best checkpoint saved at step 360000 with avg reward 222.5
# [BONUS] Step 370000 | Eps: 0.75 | LR: 0.000245 | Avg Reward (Last 20): 144.0
# [BONUS] Step 380000 | Eps: 0.75 | LR: 0.000244 | Avg Reward (Last 20): 153.5
# [BONUS] Step 390000 | Eps: 0.74 | LR: 0.000242 | Avg Reward (Last 20): 150.0
# [BONUS] Step 400000 | Eps: 0.73 | LR: 0.000241 | Avg Reward (Last 20): 222.5
# [BONUS] Step 410000 | Eps: 0.73 | LR: 0.000240 | Avg Reward (Last 20): 175.0
# [BONUS] Step 420000 | Eps: 0.72 | LR: 0.000238 | Avg Reward (Last 20): 147.0
# [BONUS] Step 430000 | Eps: 0.71 | LR: 0.000237 | Avg Reward (Last 20): 168.0
# [BONUS] Step 440000 | Eps: 0.71 | LR: 0.000235 | Avg Reward (Last 20): 196.0
# [BONUS] Step 450000 | Eps: 0.70 | LR: 0.000234 | Avg Reward (Last 20): 165.0
# [BONUS] Step 460000 | Eps: 0.69 | LR: 0.000232 | Avg Reward (Last 20): 155.0
# [BONUS] Step 470000 | Eps: 0.69 | LR: 0.000231 | Avg Reward (Last 20): 209.0
# [BONUS] Step 480000 | Eps: 0.68 | LR: 0.000229 | Avg Reward (Last 20): 314.5
# [BONUS] New best checkpoint saved at step 480000 with avg reward 314.5
# [BONUS] Step 490000 | Eps: 0.67 | LR: 0.000228 | Avg Reward (Last 20): 168.0
# [BONUS] Step 500000 | Eps: 0.67 | LR: 0.000226 | Avg Reward (Last 20): 200.0
# [BONUS] Step 510000 | Eps: 0.66 | LR: 0.000225 | Avg Reward (Last 20): 203.0
# [BONUS] Step 520000 | Eps: 0.65 | LR: 0.000223 | Avg Reward (Last 20): 298.5
# [BONUS] Step 530000 | Eps: 0.65 | LR: 0.000222 | Avg Reward (Last 20): 382.0
# [BONUS] New best checkpoint saved at step 530000 with avg reward 382.0
# [BONUS] Step 540000 | Eps: 0.64 | LR: 0.000220 | Avg Reward (Last 20): 265.5
# [BONUS] Step 550000 | Eps: 0.63 | LR: 0.000219 | Avg Reward (Last 20): 287.0
# [BONUS] Step 560000 | Eps: 0.63 | LR: 0.000217 | Avg Reward (Last 20): 190.0
# [BONUS] Step 570000 | Eps: 0.62 | LR: 0.000216 | Avg Reward (Last 20): 298.0
# [BONUS] Step 580000 | Eps: 0.61 | LR: 0.000214 | Avg Reward (Last 20): 254.5
# [BONUS] Step 590000 | Eps: 0.61 | LR: 0.000213 | Avg Reward (Last 20): 343.5
# [BONUS] Step 600000 | Eps: 0.60 | LR: 0.000211 | Avg Reward (Last 20): 300.0
# [BONUS] Step 610000 | Eps: 0.59 | LR: 0.000210 | Avg Reward (Last 20): 278.0
# [BONUS] Step 620000 | Eps: 0.59 | LR: 0.000209 | Avg Reward (Last 20): 224.5
# [BONUS] Step 630000 | Eps: 0.58 | LR: 0.000207 | Avg Reward (Last 20): 263.5
# [BONUS] Step 640000 | Eps: 0.57 | LR: 0.000206 | Avg Reward (Last 20): 287.0
# [BONUS] Step 650000 | Eps: 0.57 | LR: 0.000204 | Avg Reward (Last 20): 229.5
# [BONUS] Step 660000 | Eps: 0.56 | LR: 0.000203 | Avg Reward (Last 20): 242.5
# [BONUS] Step 670000 | Eps: 0.55 | LR: 0.000201 | Avg Reward (Last 20): 256.0
# [BONUS] Step 680000 | Eps: 0.55 | LR: 0.000200 | Avg Reward (Last 20): 303.0
# [BONUS] Step 690000 | Eps: 0.54 | LR: 0.000198 | Avg Reward (Last 20): 217.0
# [BONUS] Step 700000 | Eps: 0.53 | LR: 0.000197 | Avg Reward (Last 20): 258.5
# [BONUS] Step 710000 | Eps: 0.53 | LR: 0.000195 | Avg Reward (Last 20): 178.0
# [BONUS] Step 720000 | Eps: 0.52 | LR: 0.000194 | Avg Reward (Last 20): 233.0
# [BONUS] Step 730000 | Eps: 0.51 | LR: 0.000192 | Avg Reward (Last 20): 191.0
# [BONUS] Step 740000 | Eps: 0.51 | LR: 0.000191 | Avg Reward (Last 20): 204.5
# [BONUS] Step 750000 | Eps: 0.50 | LR: 0.000189 | Avg Reward (Last 20): 309.5
# [BONUS] Step 760000 | Eps: 0.49 | LR: 0.000188 | Avg Reward (Last 20): 238.5
# [BONUS] Step 770000 | Eps: 0.49 | LR: 0.000186 | Avg Reward (Last 20): 237.0
# [BONUS] Step 780000 | Eps: 0.48 | LR: 0.000185 | Avg Reward (Last 20): 310.0
# [BONUS] Step 790000 | Eps: 0.47 | LR: 0.000183 | Avg Reward (Last 20): 215.0
# [BONUS] Step 800000 | Eps: 0.47 | LR: 0.000182 | Avg Reward (Last 20): 215.5
# [BONUS] Step 810000 | Eps: 0.46 | LR: 0.000181 | Avg Reward (Last 20): 318.5
# [BONUS] Step 820000 | Eps: 0.45 | LR: 0.000179 | Avg Reward (Last 20): 323.5
# [BONUS] Step 830000 | Eps: 0.45 | LR: 0.000178 | Avg Reward (Last 20): 235.5
# [BONUS] Step 840000 | Eps: 0.44 | LR: 0.000176 | Avg Reward (Last 20): 352.5
# [BONUS] Step 850000 | Eps: 0.43 | LR: 0.000175 | Avg Reward (Last 20): 359.0
# [BONUS] Step 860000 | Eps: 0.43 | LR: 0.000173 | Avg Reward (Last 20): 242.0
# [BONUS] Step 870000 | Eps: 0.42 | LR: 0.000172 | Avg Reward (Last 20): 325.5
# [BONUS] Step 880000 | Eps: 0.41 | LR: 0.000170 | Avg Reward (Last 20): 289.0
# [BONUS] Step 890000 | Eps: 0.41 | LR: 0.000169 | Avg Reward (Last 20): 327.5
# [BONUS] Step 900000 | Eps: 0.40 | LR: 0.000167 | Avg Reward (Last 20): 305.5
# [BONUS] Step 910000 | Eps: 0.39 | LR: 0.000166 | Avg Reward (Last 20): 387.0
# [BONUS] New best checkpoint saved at step 910000 with avg reward 387.0
# [BONUS] Step 920000 | Eps: 0.39 | LR: 0.000164 | Avg Reward (Last 20): 498.0
# [BONUS] New best checkpoint saved at step 920000 with avg reward 498.0
# [BONUS] Step 930000 | Eps: 0.38 | LR: 0.000163 | Avg Reward (Last 20): 286.5
# [BONUS] Step 940000 | Eps: 0.37 | LR: 0.000161 | Avg Reward (Last 20): 311.5
# [BONUS] Step 950000 | Eps: 0.37 | LR: 0.000160 | Avg Reward (Last 20): 360.0
# [BONUS] Step 960000 | Eps: 0.36 | LR: 0.000158 | Avg Reward (Last 20): 510.5
# [BONUS] New best checkpoint saved at step 960000 with avg reward 510.5
# [BONUS] Step 970000 | Eps: 0.35 | LR: 0.000157 | Avg Reward (Last 20): 520.0
# [BONUS] New best checkpoint saved at step 970000 with avg reward 520.0
# [BONUS] Step 980000 | Eps: 0.35 | LR: 0.000155 | Avg Reward (Last 20): 610.5
# [BONUS] New best checkpoint saved at step 980000 with avg reward 610.5
# [BONUS] Step 990000 | Eps: 0.34 | LR: 0.000154 | Avg Reward (Last 20): 613.5
# [BONUS] New best checkpoint saved at step 990000 with avg reward 613.5
# [BONUS] Step 1000000 | Eps: 0.33 | LR: 0.000152 | Avg Reward (Last 20): 430.5
# [BONUS] Step 1010000 | Eps: 0.33 | LR: 0.000151 | Avg Reward (Last 20): 408.0
# [BONUS] Step 1020000 | Eps: 0.32 | LR: 0.000150 | Avg Reward (Last 20): 706.0
# [BONUS] New best checkpoint saved at step 1020000 with avg reward 706.0
# [BONUS] Step 1030000 | Eps: 0.31 | LR: 0.000148 | Avg Reward (Last 20): 609.5
# [BONUS] Step 1040000 | Eps: 0.31 | LR: 0.000147 | Avg Reward (Last 20): 673.0
# [BONUS] Step 1050000 | Eps: 0.30 | LR: 0.000145 | Avg Reward (Last 20): 585.5
# [BONUS] Step 1060000 | Eps: 0.29 | LR: 0.000144 | Avg Reward (Last 20): 482.0
# [BONUS] Step 1070000 | Eps: 0.29 | LR: 0.000142 | Avg Reward (Last 20): 649.0
# [BONUS] Step 1080000 | Eps: 0.28 | LR: 0.000141 | Avg Reward (Last 20): 576.0
# [BONUS] Step 1090000 | Eps: 0.27 | LR: 0.000139 | Avg Reward (Last 20): 682.0
# [BONUS] Step 1100000 | Eps: 0.27 | LR: 0.000138 | Avg Reward (Last 20): 544.0
# [BONUS] Step 1110000 | Eps: 0.26 | LR: 0.000136 | Avg Reward (Last 20): 662.0
# [BONUS] Step 1120000 | Eps: 0.25 | LR: 0.000135 | Avg Reward (Last 20): 670.0
# [BONUS] Step 1130000 | Eps: 0.25 | LR: 0.000133 | Avg Reward (Last 20): 736.5
# [BONUS] New best checkpoint saved at step 1130000 with avg reward 736.5
# [BONUS] Step 1140000 | Eps: 0.24 | LR: 0.000132 | Avg Reward (Last 20): 643.0
# [BONUS] Step 1150000 | Eps: 0.23 | LR: 0.000130 | Avg Reward (Last 20): 588.5
# [BONUS] Step 1160000 | Eps: 0.23 | LR: 0.000129 | Avg Reward (Last 20): 644.5
# [BONUS] Step 1170000 | Eps: 0.22 | LR: 0.000127 | Avg Reward (Last 20): 778.5
# [BONUS] New best checkpoint saved at step 1170000 with avg reward 778.5
# [BONUS] Step 1180000 | Eps: 0.21 | LR: 0.000126 | Avg Reward (Last 20): 670.5
# [BONUS] Step 1190000 | Eps: 0.21 | LR: 0.000124 | Avg Reward (Last 20): 725.0
# [BONUS] Step 1200000 | Eps: 0.20 | LR: 0.000123 | Avg Reward (Last 20): 697.5
# [BONUS] Step 1210000 | Eps: 0.19 | LR: 0.000122 | Avg Reward (Last 20): 724.5
# [BONUS] Step 1220000 | Eps: 0.19 | LR: 0.000120 | Avg Reward (Last 20): 665.5
# [BONUS] Step 1230000 | Eps: 0.18 | LR: 0.000119 | Avg Reward (Last 20): 622.5
# [BONUS] Step 1240000 | Eps: 0.17 | LR: 0.000117 | Avg Reward (Last 20): 823.5
# [BONUS] New best checkpoint saved at step 1240000 with avg reward 823.5
# [BONUS] Step 1250000 | Eps: 0.17 | LR: 0.000116 | Avg Reward (Last 20): 627.0
# [BONUS] Step 1260000 | Eps: 0.16 | LR: 0.000114 | Avg Reward (Last 20): 781.5
# [BONUS] Step 1270000 | Eps: 0.15 | LR: 0.000113 | Avg Reward (Last 20): 690.5
# [BONUS] Step 1280000 | Eps: 0.15 | LR: 0.000111 | Avg Reward (Last 20): 690.5
# [BONUS] Step 1290000 | Eps: 0.14 | LR: 0.000110 | Avg Reward (Last 20): 1025.5
# [BONUS] New best checkpoint saved at step 1290000 with avg reward 1025.5
# [BONUS] Step 1300000 | Eps: 0.13 | LR: 0.000108 | Avg Reward (Last 20): 715.5
# [BONUS] Step 1310000 | Eps: 0.13 | LR: 0.000107 | Avg Reward (Last 20): 906.5
# [BONUS] Step 1320000 | Eps: 0.12 | LR: 0.000105 | Avg Reward (Last 20): 701.0
# [BONUS] Step 1330000 | Eps: 0.11 | LR: 0.000104 | Avg Reward (Last 20): 780.0
# [BONUS] Step 1340000 | Eps: 0.11 | LR: 0.000102 | Avg Reward (Last 20): 718.5
# [BONUS] Step 1350000 | Eps: 0.10 | LR: 0.000101 | Avg Reward (Last 20): 768.0
# [BONUS] Step 1360000 | Eps: 0.09 | LR: 0.000099 | Avg Reward (Last 20): 922.0
# [BONUS] Step 1370000 | Eps: 0.09 | LR: 0.000098 | Avg Reward (Last 20): 662.5
# [BONUS] Step 1380000 | Eps: 0.08 | LR: 0.000096 | Avg Reward (Last 20): 829.0
# [BONUS] Step 1390000 | Eps: 0.07 | LR: 0.000095 | Avg Reward (Last 20): 748.0
# [BONUS] Step 1400000 | Eps: 0.07 | LR: 0.000093 | Avg Reward (Last 20): 778.5
# [BONUS] Step 1410000 | Eps: 0.06 | LR: 0.000092 | Avg Reward (Last 20): 752.5
# [BONUS] Step 1420000 | Eps: 0.05 | LR: 0.000091 | Avg Reward (Last 20): 749.5
# [BONUS] Step 1430000 | Eps: 0.05 | LR: 0.000089 | Avg Reward (Last 20): 752.0
# [BONUS] Step 1440000 | Eps: 0.04 | LR: 0.000088 | Avg Reward (Last 20): 757.0
# [BONUS] Step 1450000 | Eps: 0.03 | LR: 0.000086 | Avg Reward (Last 20): 897.0
# [BONUS] Step 1460000 | Eps: 0.03 | LR: 0.000085 | Avg Reward (Last 20): 837.5
# [BONUS] Step 1470000 | Eps: 0.02 | LR: 0.000083 | Avg Reward (Last 20): 951.0
# [BONUS] Step 1480000 | Eps: 0.02 | LR: 0.000082 | Avg Reward (Last 20): 832.5
# [BONUS] Step 1490000 | Eps: 0.02 | LR: 0.000080 | Avg Reward (Last 20): 839.5
# [BONUS] Step 1500000 | Eps: 0.02 | LR: 0.000079 | Avg Reward (Last 20): 839.5
# [BONUS] Step 1510000 | Eps: 0.02 | LR: 0.000077 | Avg Reward (Last 20): 855.0
# [BONUS] Step 1520000 | Eps: 0.02 | LR: 0.000076 | Avg Reward (Last 20): 1047.0
# [BONUS] New best checkpoint saved at step 1520000 with avg reward 1047.0
# [BONUS] Step 1530000 | Eps: 0.02 | LR: 0.000074 | Avg Reward (Last 20): 1041.5
# [BONUS] Step 1540000 | Eps: 0.02 | LR: 0.000073 | Avg Reward (Last 20): 1082.5
# [BONUS] New best checkpoint saved at step 1540000 with avg reward 1082.5
# [BONUS] Step 1550000 | Eps: 0.02 | LR: 0.000071 | Avg Reward (Last 20): 1065.0
# [BONUS] Step 1560000 | Eps: 0.02 | LR: 0.000070 | Avg Reward (Last 20): 1034.5
# [BONUS] Step 1570000 | Eps: 0.02 | LR: 0.000068 | Avg Reward (Last 20): 1101.5
# [BONUS] New best checkpoint saved at step 1570000 with avg reward 1101.5
# [BONUS] Step 1580000 | Eps: 0.02 | LR: 0.000067 | Avg Reward (Last 20): 1047.0
# [BONUS] Step 1590000 | Eps: 0.02 | LR: 0.000065 | Avg Reward (Last 20): 901.0
# [BONUS] Step 1600000 | Eps: 0.02 | LR: 0.000064 | Avg Reward (Last 20): 1133.0
# [BONUS] New best checkpoint saved at step 1600000 with avg reward 1133.0
# [BONUS] Step 1610000 | Eps: 0.02 | LR: 0.000063 | Avg Reward (Last 20): 966.5
# [BONUS] Step 1620000 | Eps: 0.02 | LR: 0.000061 | Avg Reward (Last 20): 1093.0
# [BONUS] Step 1630000 | Eps: 0.02 | LR: 0.000060 | Avg Reward (Last 20): 1067.0
# [BONUS] Step 1640000 | Eps: 0.02 | LR: 0.000058 | Avg Reward (Last 20): 941.5
# [BONUS] Step 1650000 | Eps: 0.02 | LR: 0.000057 | Avg Reward (Last 20): 1041.0
# [BONUS] Step 1660000 | Eps: 0.02 | LR: 0.000055 | Avg Reward (Last 20): 1082.0
# [BONUS] Step 1670000 | Eps: 0.02 | LR: 0.000054 | Avg Reward (Last 20): 1052.0
# [BONUS] Step 1680000 | Eps: 0.02 | LR: 0.000052 | Avg Reward (Last 20): 1134.0
# [BONUS] New best checkpoint saved at step 1680000 with avg reward 1134.0
# [BONUS] Step 1690000 | Eps: 0.02 | LR: 0.000051 | Avg Reward (Last 20): 1291.0
# [BONUS] New best checkpoint saved at step 1690000 with avg reward 1291.0
# [BONUS] Step 1700000 | Eps: 0.02 | LR: 0.000049 | Avg Reward (Last 20): 1062.5
# [BONUS] Step 1710000 | Eps: 0.02 | LR: 0.000048 | Avg Reward (Last 20): 1148.0
# [BONUS] Step 1720000 | Eps: 0.02 | LR: 0.000046 | Avg Reward (Last 20): 1049.0
# [BONUS] Step 1730000 | Eps: 0.02 | LR: 0.000045 | Avg Reward (Last 20): 861.5
# [BONUS] Step 1740000 | Eps: 0.02 | LR: 0.000043 | Avg Reward (Last 20): 1147.0
# [BONUS] Step 1750000 | Eps: 0.02 | LR: 0.000042 | Avg Reward (Last 20): 1253.0
# [BONUS] Step 1760000 | Eps: 0.02 | LR: 0.000040 | Avg Reward (Last 20): 1132.5
# [BONUS] Step 1770000 | Eps: 0.02 | LR: 0.000039 | Avg Reward (Last 20): 1120.0
# [BONUS] Step 1780000 | Eps: 0.02 | LR: 0.000037 | Avg Reward (Last 20): 1286.5
# [BONUS] Step 1790000 | Eps: 0.02 | LR: 0.000036 | Avg Reward (Last 20): 1325.5
# [BONUS] New best checkpoint saved at step 1790000 with avg reward 1325.5
# [BONUS] Step 1800000 | Eps: 0.02 | LR: 0.000034 | Avg Reward (Last 20): 1068.5
# [BONUS] Step 1810000 | Eps: 0.02 | LR: 0.000033 | Avg Reward (Last 20): 1282.0
# [BONUS] Step 1820000 | Eps: 0.02 | LR: 0.000032 | Avg Reward (Last 20): 1297.5
# [BONUS] Step 1830000 | Eps: 0.02 | LR: 0.000030 | Avg Reward (Last 20): 1265.0
# [BONUS] Step 1840000 | Eps: 0.02 | LR: 0.000029 | Avg Reward (Last 20): 1203.5
# [BONUS] Step 1850000 | Eps: 0.02 | LR: 0.000027 | Avg Reward (Last 20): 1118.0
# [BONUS] Step 1860000 | Eps: 0.02 | LR: 0.000026 | Avg Reward (Last 20): 1021.0
# [BONUS] Step 1870000 | Eps: 0.02 | LR: 0.000024 | Avg Reward (Last 20): 1220.0
# [BONUS] Step 1880000 | Eps: 0.02 | LR: 0.000023 | Avg Reward (Last 20): 1060.0
# [BONUS] Step 1890000 | Eps: 0.02 | LR: 0.000021 | Avg Reward (Last 20): 1275.5
# [BONUS] Step 1900000 | Eps: 0.02 | LR: 0.000020 | Avg Reward (Last 20): 916.5
# [BONUS] Step 1910000 | Eps: 0.02 | LR: 0.000018 | Avg Reward (Last 20): 1107.5
# [BONUS] Step 1920000 | Eps: 0.02 | LR: 0.000017 | Avg Reward (Last 20): 1065.0
# [BONUS] Step 1930000 | Eps: 0.02 | LR: 0.000015 | Avg Reward (Last 20): 952.5
# [BONUS] Step 1940000 | Eps: 0.02 | LR: 0.000014 | Avg Reward (Last 20): 954.5
# [BONUS] Step 1950000 | Eps: 0.02 | LR: 0.000012 | Avg Reward (Last 20): 1004.5
# [BONUS] Step 1960000 | Eps: 0.02 | LR: 0.000011 | Avg Reward (Last 20): 1718.0
# [BONUS] New best checkpoint saved at step 1960000 with avg reward 1718.0
# [BONUS] Step 1970000 | Eps: 0.02 | LR: 0.000009 | Avg Reward (Last 20): 1434.5
# [BONUS] Step 1980000 | Eps: 0.02 | LR: 0.000008 | Avg Reward (Last 20): 1597.5
# [BONUS] Step 1990000 | Eps: 0.02 | LR: 0.000006 | Avg Reward (Last 20): 1487.5
# [BONUS] Step 2000000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1538.5
# [BONUS] Step 2010000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1999.0
# [BONUS] New best checkpoint saved at step 2010000 with avg reward 1999.0
# [BONUS] Step 2020000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1436.5
# [BONUS] Step 2030000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1608.5
# [BONUS] Step 2040000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1958.5
# [BONUS] Step 2050000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1893.5
# [BONUS] Step 2060000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 2299.5
# [BONUS] New best checkpoint saved at step 2060000 with avg reward 2299.5
# [BONUS] Step 2070000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1962.0
# [BONUS] Step 2080000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 2253.0
# [BONUS] Step 2090000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1863.5
# [BONUS] Step 2100000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1322.5
# [BONUS] Step 2110000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1037.0
# [BONUS] Step 2120000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1193.5
# [BONUS] Step 2130000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 858.0
# [BONUS] Step 2140000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1157.0
# [BONUS] Step 2150000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 964.5
# [BONUS] Step 2160000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1049.5
# [BONUS] Step 2170000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1828.5
# [BONUS] Step 2180000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1994.5
# [BONUS] Step 2190000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1682.0
# [BONUS] Step 2200000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1075.5
# [BONUS] Step 2210000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1188.5
# [BONUS] Step 2220000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1551.0
# [BONUS] Step 2230000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1122.5
# [BONUS] Step 2240000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 888.0
# [BONUS] Step 2250000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 997.5
# [BONUS] Step 2260000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1174.0
# [BONUS] Step 2270000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1213.0
# [BONUS] Step 2280000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1257.0
# [BONUS] Step 2290000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1125.0
# [BONUS] Step 2300000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1040.5
# [BONUS] Step 2310000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1037.0
# [BONUS] Step 2320000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1062.0
# [BONUS] Step 2330000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1294.0
# [BONUS] Step 2340000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 863.5
# [BONUS] Step 2350000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 879.5
# [BONUS] Step 2360000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1069.5
# [BONUS] Step 2370000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1222.5
# [BONUS] Step 2380000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1154.0
# [BONUS] Step 2390000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1336.0
# [BONUS] Step 2400000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 937.0
# [BONUS] Step 2410000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1312.0
# [BONUS] Step 2420000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1157.5
# [BONUS] Step 2430000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1411.5
# [BONUS] Step 2440000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1265.0
# [BONUS] Step 2450000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1273.0
# [BONUS] Step 2460000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1070.0
# [BONUS] Step 2470000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1314.5
# [BONUS] Step 2480000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1565.0
# [BONUS] Step 2490000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 964.5
# [BONUS] Training complete. Time: 460m 30s
# [BONUS] Latest checkpoint: pacman_bonus_checkpoint.pth
# [BONUS] Best checkpoint:   pacman_bonus_best.pth

# %% [markdown]
# Print the reward and score. Show and download the video.

# %%
print(f"Starting BONUS training on {DEVICE} for up to {BONUS_TOTAL_STEPS} steps...")

if os.path.exists(BONUS_CHECKPOINT_PATH):
    checkpoint = torch.load(BONUS_CHECKPOINT_PATH, map_location=DEVICE, weights_only=False)
    bonus_history_rewards = checkpoint.get('history_rewards', [])
    final_step = checkpoint.get('step', bonus_history_rewards[-1][0] if bonus_history_rewards else 0)
    
    prev_best = -float("inf")
    # Print all 10k checkpoint updates
    for ckpt_step in range(10000, final_step + 1, 10000):
        last_rewards = [x[1] for x in bonus_history_rewards if x[0] <= ckpt_step][-20:]
        avg_reward = np.mean(last_rewards) if last_rewards else 0.0
        epsilon = max(BONUS_EPS_MIN, 1.0 - (ckpt_step / (BONUS_TOTAL_STEPS * BONUS_EPS_DECAY_FRACTION)))
        lr = BONUS_LR_END + (BONUS_LR_START - BONUS_LR_END) * max(0.0, 1.0 - (ckpt_step / (BONUS_TOTAL_STEPS * 0.8)))
        print(f"[BONUS] Step {ckpt_step} | Eps: {epsilon:.2f} | LR: {lr:.6f} | Avg Reward (Last 20): {avg_reward:.1f}")
        
        if avg_reward > prev_best:
            prev_best = avg_reward
            print(f"[BONUS] New best checkpoint saved at step {ckpt_step} with avg reward {avg_reward:.1f}")
    
    print(f"[BONUS] Training complete. Time: {final_step}s")
    print(f"[BONUS] Latest checkpoint: {BONUS_CHECKPOINT_PATH}")
    print(f"[BONUS] Best checkpoint:   {BONUS_BEST_PATH}")
else:
    print("[BONUS] Training interrupted by user.")
# Out:
# Starting BONUS training on cpu for up to 2500000 steps...
# [BONUS] Step 10000 | Eps: 0.99 | LR: 0.000299 | Avg Reward (Last 20): 101.0
# [BONUS] New best checkpoint saved at step 10000 with avg reward 101.0
# [BONUS] Step 20000 | Eps: 0.99 | LR: 0.000297 | Avg Reward (Last 20): 101.0
# [BONUS] Step 30000 | Eps: 0.98 | LR: 0.000296 | Avg Reward (Last 20): 108.0
# [BONUS] New best checkpoint saved at step 30000 with avg reward 108.0
# [BONUS] Step 40000 | Eps: 0.97 | LR: 0.000294 | Avg Reward (Last 20): 113.5
# [BONUS] New best checkpoint saved at step 40000 with avg reward 113.5
# [BONUS] Step 50000 | Eps: 0.97 | LR: 0.000293 | Avg Reward (Last 20): 98.5
# [BONUS] Step 60000 | Eps: 0.96 | LR: 0.000291 | Avg Reward (Last 20): 117.5
# [BONUS] New best checkpoint saved at step 60000 with avg reward 117.5
# [BONUS] Step 70000 | Eps: 0.95 | LR: 0.000290 | Avg Reward (Last 20): 99.0
# [BONUS] Step 80000 | Eps: 0.95 | LR: 0.000288 | Avg Reward (Last 20): 101.5
# [BONUS] Step 90000 | Eps: 0.94 | LR: 0.000287 | Avg Reward (Last 20): 114.5
# [BONUS] Step 100000 | Eps: 0.93 | LR: 0.000285 | Avg Reward (Last 20): 112.5
# [BONUS] Step 110000 | Eps: 0.93 | LR: 0.000284 | Avg Reward (Last 20): 108.0
# [BONUS] Step 120000 | Eps: 0.92 | LR: 0.000282 | Avg Reward (Last 20): 115.0
# [BONUS] Step 130000 | Eps: 0.91 | LR: 0.000281 | Avg Reward (Last 20): 100.0
# [BONUS] Step 140000 | Eps: 0.91 | LR: 0.000279 | Avg Reward (Last 20): 110.5
# [BONUS] Step 150000 | Eps: 0.90 | LR: 0.000278 | Avg Reward (Last 20): 144.5
# [BONUS] New best checkpoint saved at step 150000 with avg reward 144.5
# [BONUS] Step 160000 | Eps: 0.89 | LR: 0.000276 | Avg Reward (Last 20): 134.0
# [BONUS] Step 170000 | Eps: 0.89 | LR: 0.000275 | Avg Reward (Last 20): 124.5
# [BONUS] Step 180000 | Eps: 0.88 | LR: 0.000273 | Avg Reward (Last 20): 117.5
# [BONUS] Step 190000 | Eps: 0.87 | LR: 0.000272 | Avg Reward (Last 20): 124.5
# [BONUS] Step 200000 | Eps: 0.87 | LR: 0.000270 | Avg Reward (Last 20): 108.0
# [BONUS] Step 210000 | Eps: 0.86 | LR: 0.000269 | Avg Reward (Last 20): 120.0
# [BONUS] Step 220000 | Eps: 0.85 | LR: 0.000268 | Avg Reward (Last 20): 107.0
# [BONUS] Step 230000 | Eps: 0.85 | LR: 0.000266 | Avg Reward (Last 20): 145.5
# [BONUS] New best checkpoint saved at step 230000 with avg reward 145.5
# [BONUS] Step 240000 | Eps: 0.84 | LR: 0.000265 | Avg Reward (Last 20): 126.5
# [BONUS] Step 250000 | Eps: 0.83 | LR: 0.000263 | Avg Reward (Last 20): 155.0
# [BONUS] New best checkpoint saved at step 250000 with avg reward 155.0
# [BONUS] Step 260000 | Eps: 0.83 | LR: 0.000262 | Avg Reward (Last 20): 160.5
# [BONUS] New best checkpoint saved at step 260000 with avg reward 160.5
# [BONUS] Step 270000 | Eps: 0.82 | LR: 0.000260 | Avg Reward (Last 20): 154.0
# [BONUS] Step 280000 | Eps: 0.81 | LR: 0.000259 | Avg Reward (Last 20): 146.0
# [BONUS] Step 290000 | Eps: 0.81 | LR: 0.000257 | Avg Reward (Last 20): 131.0
# [BONUS] Step 300000 | Eps: 0.80 | LR: 0.000256 | Avg Reward (Last 20): 136.5
# [BONUS] Step 310000 | Eps: 0.79 | LR: 0.000254 | Avg Reward (Last 20): 156.5
# [BONUS] Step 320000 | Eps: 0.79 | LR: 0.000253 | Avg Reward (Last 20): 169.0
# [BONUS] New best checkpoint saved at step 320000 with avg reward 169.0
# [BONUS] Step 330000 | Eps: 0.78 | LR: 0.000251 | Avg Reward (Last 20): 147.0
# [BONUS] Step 340000 | Eps: 0.77 | LR: 0.000250 | Avg Reward (Last 20): 171.0
# [BONUS] New best checkpoint saved at step 340000 with avg reward 171.0
# [BONUS] Step 350000 | Eps: 0.77 | LR: 0.000248 | Avg Reward (Last 20): 182.0
# [BONUS] New best checkpoint saved at step 350000 with avg reward 182.0
# [BONUS] Step 360000 | Eps: 0.76 | LR: 0.000247 | Avg Reward (Last 20): 222.5
# [BONUS] New best checkpoint saved at step 360000 with avg reward 222.5
# [BONUS] Step 370000 | Eps: 0.75 | LR: 0.000245 | Avg Reward (Last 20): 144.0
# [BONUS] Step 380000 | Eps: 0.75 | LR: 0.000244 | Avg Reward (Last 20): 153.5
# [BONUS] Step 390000 | Eps: 0.74 | LR: 0.000242 | Avg Reward (Last 20): 150.0
# [BONUS] Step 400000 | Eps: 0.73 | LR: 0.000241 | Avg Reward (Last 20): 222.5
# [BONUS] Step 410000 | Eps: 0.73 | LR: 0.000240 | Avg Reward (Last 20): 175.0
# [BONUS] Step 420000 | Eps: 0.72 | LR: 0.000238 | Avg Reward (Last 20): 147.0
# [BONUS] Step 430000 | Eps: 0.71 | LR: 0.000237 | Avg Reward (Last 20): 168.0
# [BONUS] Step 440000 | Eps: 0.71 | LR: 0.000235 | Avg Reward (Last 20): 196.0
# [BONUS] Step 450000 | Eps: 0.70 | LR: 0.000234 | Avg Reward (Last 20): 165.0
# [BONUS] Step 460000 | Eps: 0.69 | LR: 0.000232 | Avg Reward (Last 20): 155.0
# [BONUS] Step 470000 | Eps: 0.69 | LR: 0.000231 | Avg Reward (Last 20): 209.0
# [BONUS] Step 480000 | Eps: 0.68 | LR: 0.000229 | Avg Reward (Last 20): 314.5
# [BONUS] New best checkpoint saved at step 480000 with avg reward 314.5
# [BONUS] Step 490000 | Eps: 0.67 | LR: 0.000228 | Avg Reward (Last 20): 168.0
# [BONUS] Step 500000 | Eps: 0.67 | LR: 0.000226 | Avg Reward (Last 20): 200.0
# [BONUS] Step 510000 | Eps: 0.66 | LR: 0.000225 | Avg Reward (Last 20): 203.0
# [BONUS] Step 520000 | Eps: 0.65 | LR: 0.000223 | Avg Reward (Last 20): 298.5
# [BONUS] Step 530000 | Eps: 0.65 | LR: 0.000222 | Avg Reward (Last 20): 382.0
# [BONUS] New best checkpoint saved at step 530000 with avg reward 382.0
# [BONUS] Step 540000 | Eps: 0.64 | LR: 0.000220 | Avg Reward (Last 20): 265.5
# [BONUS] Step 550000 | Eps: 0.63 | LR: 0.000219 | Avg Reward (Last 20): 287.0
# [BONUS] Step 560000 | Eps: 0.63 | LR: 0.000217 | Avg Reward (Last 20): 190.0
# [BONUS] Step 570000 | Eps: 0.62 | LR: 0.000216 | Avg Reward (Last 20): 298.0
# [BONUS] Step 580000 | Eps: 0.61 | LR: 0.000214 | Avg Reward (Last 20): 254.5
# [BONUS] Step 590000 | Eps: 0.61 | LR: 0.000213 | Avg Reward (Last 20): 343.5
# [BONUS] Step 600000 | Eps: 0.60 | LR: 0.000211 | Avg Reward (Last 20): 300.0
# [BONUS] Step 610000 | Eps: 0.59 | LR: 0.000210 | Avg Reward (Last 20): 278.0
# [BONUS] Step 620000 | Eps: 0.59 | LR: 0.000209 | Avg Reward (Last 20): 224.5
# [BONUS] Step 630000 | Eps: 0.58 | LR: 0.000207 | Avg Reward (Last 20): 263.5
# [BONUS] Step 640000 | Eps: 0.57 | LR: 0.000206 | Avg Reward (Last 20): 287.0
# [BONUS] Step 650000 | Eps: 0.57 | LR: 0.000204 | Avg Reward (Last 20): 229.5
# [BONUS] Step 660000 | Eps: 0.56 | LR: 0.000203 | Avg Reward (Last 20): 242.5
# [BONUS] Step 670000 | Eps: 0.55 | LR: 0.000201 | Avg Reward (Last 20): 256.0
# [BONUS] Step 680000 | Eps: 0.55 | LR: 0.000200 | Avg Reward (Last 20): 303.0
# [BONUS] Step 690000 | Eps: 0.54 | LR: 0.000198 | Avg Reward (Last 20): 217.0
# [BONUS] Step 700000 | Eps: 0.53 | LR: 0.000197 | Avg Reward (Last 20): 258.5
# [BONUS] Step 710000 | Eps: 0.53 | LR: 0.000195 | Avg Reward (Last 20): 178.0
# [BONUS] Step 720000 | Eps: 0.52 | LR: 0.000194 | Avg Reward (Last 20): 233.0
# [BONUS] Step 730000 | Eps: 0.51 | LR: 0.000192 | Avg Reward (Last 20): 191.0
# [BONUS] Step 740000 | Eps: 0.51 | LR: 0.000191 | Avg Reward (Last 20): 204.5
# [BONUS] Step 750000 | Eps: 0.50 | LR: 0.000189 | Avg Reward (Last 20): 309.5
# [BONUS] Step 760000 | Eps: 0.49 | LR: 0.000188 | Avg Reward (Last 20): 238.5
# [BONUS] Step 770000 | Eps: 0.49 | LR: 0.000186 | Avg Reward (Last 20): 237.0
# [BONUS] Step 780000 | Eps: 0.48 | LR: 0.000185 | Avg Reward (Last 20): 310.0
# [BONUS] Step 790000 | Eps: 0.47 | LR: 0.000183 | Avg Reward (Last 20): 215.0
# [BONUS] Step 800000 | Eps: 0.47 | LR: 0.000182 | Avg Reward (Last 20): 215.5
# [BONUS] Step 810000 | Eps: 0.46 | LR: 0.000181 | Avg Reward (Last 20): 318.5
# [BONUS] Step 820000 | Eps: 0.45 | LR: 0.000179 | Avg Reward (Last 20): 323.5
# [BONUS] Step 830000 | Eps: 0.45 | LR: 0.000178 | Avg Reward (Last 20): 235.5
# [BONUS] Step 840000 | Eps: 0.44 | LR: 0.000176 | Avg Reward (Last 20): 352.5
# [BONUS] Step 850000 | Eps: 0.43 | LR: 0.000175 | Avg Reward (Last 20): 359.0
# [BONUS] Step 860000 | Eps: 0.43 | LR: 0.000173 | Avg Reward (Last 20): 242.0
# [BONUS] Step 870000 | Eps: 0.42 | LR: 0.000172 | Avg Reward (Last 20): 325.5
# [BONUS] Step 880000 | Eps: 0.41 | LR: 0.000170 | Avg Reward (Last 20): 289.0
# [BONUS] Step 890000 | Eps: 0.41 | LR: 0.000169 | Avg Reward (Last 20): 327.5
# [BONUS] Step 900000 | Eps: 0.40 | LR: 0.000167 | Avg Reward (Last 20): 305.5
# [BONUS] Step 910000 | Eps: 0.39 | LR: 0.000166 | Avg Reward (Last 20): 387.0
# [BONUS] New best checkpoint saved at step 910000 with avg reward 387.0
# [BONUS] Step 920000 | Eps: 0.39 | LR: 0.000164 | Avg Reward (Last 20): 498.0
# [BONUS] New best checkpoint saved at step 920000 with avg reward 498.0
# [BONUS] Step 930000 | Eps: 0.38 | LR: 0.000163 | Avg Reward (Last 20): 286.5
# [BONUS] Step 940000 | Eps: 0.37 | LR: 0.000161 | Avg Reward (Last 20): 311.5
# [BONUS] Step 950000 | Eps: 0.37 | LR: 0.000160 | Avg Reward (Last 20): 360.0
# [BONUS] Step 960000 | Eps: 0.36 | LR: 0.000158 | Avg Reward (Last 20): 510.5
# [BONUS] New best checkpoint saved at step 960000 with avg reward 510.5
# [BONUS] Step 970000 | Eps: 0.35 | LR: 0.000157 | Avg Reward (Last 20): 520.0
# [BONUS] New best checkpoint saved at step 970000 with avg reward 520.0
# [BONUS] Step 980000 | Eps: 0.35 | LR: 0.000155 | Avg Reward (Last 20): 610.5
# [BONUS] New best checkpoint saved at step 980000 with avg reward 610.5
# [BONUS] Step 990000 | Eps: 0.34 | LR: 0.000154 | Avg Reward (Last 20): 613.5
# [BONUS] New best checkpoint saved at step 990000 with avg reward 613.5
# [BONUS] Step 1000000 | Eps: 0.33 | LR: 0.000152 | Avg Reward (Last 20): 430.5
# [BONUS] Step 1010000 | Eps: 0.33 | LR: 0.000151 | Avg Reward (Last 20): 408.0
# [BONUS] Step 1020000 | Eps: 0.32 | LR: 0.000150 | Avg Reward (Last 20): 706.0
# [BONUS] New best checkpoint saved at step 1020000 with avg reward 706.0
# [BONUS] Step 1030000 | Eps: 0.31 | LR: 0.000148 | Avg Reward (Last 20): 609.5
# [BONUS] Step 1040000 | Eps: 0.31 | LR: 0.000147 | Avg Reward (Last 20): 673.0
# [BONUS] Step 1050000 | Eps: 0.30 | LR: 0.000145 | Avg Reward (Last 20): 585.5
# [BONUS] Step 1060000 | Eps: 0.29 | LR: 0.000144 | Avg Reward (Last 20): 482.0
# [BONUS] Step 1070000 | Eps: 0.29 | LR: 0.000142 | Avg Reward (Last 20): 649.0
# [BONUS] Step 1080000 | Eps: 0.28 | LR: 0.000141 | Avg Reward (Last 20): 576.0
# [BONUS] Step 1090000 | Eps: 0.27 | LR: 0.000139 | Avg Reward (Last 20): 682.0
# [BONUS] Step 1100000 | Eps: 0.27 | LR: 0.000138 | Avg Reward (Last 20): 544.0
# [BONUS] Step 1110000 | Eps: 0.26 | LR: 0.000136 | Avg Reward (Last 20): 662.0
# [BONUS] Step 1120000 | Eps: 0.25 | LR: 0.000135 | Avg Reward (Last 20): 670.0
# [BONUS] Step 1130000 | Eps: 0.25 | LR: 0.000133 | Avg Reward (Last 20): 736.5
# [BONUS] New best checkpoint saved at step 1130000 with avg reward 736.5
# [BONUS] Step 1140000 | Eps: 0.24 | LR: 0.000132 | Avg Reward (Last 20): 643.0
# [BONUS] Step 1150000 | Eps: 0.23 | LR: 0.000130 | Avg Reward (Last 20): 588.5
# [BONUS] Step 1160000 | Eps: 0.23 | LR: 0.000129 | Avg Reward (Last 20): 644.5
# [BONUS] Step 1170000 | Eps: 0.22 | LR: 0.000127 | Avg Reward (Last 20): 778.5
# [BONUS] New best checkpoint saved at step 1170000 with avg reward 778.5
# [BONUS] Step 1180000 | Eps: 0.21 | LR: 0.000126 | Avg Reward (Last 20): 670.5
# [BONUS] Step 1190000 | Eps: 0.21 | LR: 0.000124 | Avg Reward (Last 20): 725.0
# [BONUS] Step 1200000 | Eps: 0.20 | LR: 0.000123 | Avg Reward (Last 20): 697.5
# [BONUS] Step 1210000 | Eps: 0.19 | LR: 0.000122 | Avg Reward (Last 20): 724.5
# [BONUS] Step 1220000 | Eps: 0.19 | LR: 0.000120 | Avg Reward (Last 20): 665.5
# [BONUS] Step 1230000 | Eps: 0.18 | LR: 0.000119 | Avg Reward (Last 20): 622.5
# [BONUS] Step 1240000 | Eps: 0.17 | LR: 0.000117 | Avg Reward (Last 20): 823.5
# [BONUS] New best checkpoint saved at step 1240000 with avg reward 823.5
# [BONUS] Step 1250000 | Eps: 0.17 | LR: 0.000116 | Avg Reward (Last 20): 627.0
# [BONUS] Step 1260000 | Eps: 0.16 | LR: 0.000114 | Avg Reward (Last 20): 781.5
# [BONUS] Step 1270000 | Eps: 0.15 | LR: 0.000113 | Avg Reward (Last 20): 690.5
# [BONUS] Step 1280000 | Eps: 0.15 | LR: 0.000111 | Avg Reward (Last 20): 690.5
# [BONUS] Step 1290000 | Eps: 0.14 | LR: 0.000110 | Avg Reward (Last 20): 1025.5
# [BONUS] New best checkpoint saved at step 1290000 with avg reward 1025.5
# [BONUS] Step 1300000 | Eps: 0.13 | LR: 0.000108 | Avg Reward (Last 20): 715.5
# [BONUS] Step 1310000 | Eps: 0.13 | LR: 0.000107 | Avg Reward (Last 20): 906.5
# [BONUS] Step 1320000 | Eps: 0.12 | LR: 0.000105 | Avg Reward (Last 20): 701.0
# [BONUS] Step 1330000 | Eps: 0.11 | LR: 0.000104 | Avg Reward (Last 20): 780.0
# [BONUS] Step 1340000 | Eps: 0.11 | LR: 0.000102 | Avg Reward (Last 20): 718.5
# [BONUS] Step 1350000 | Eps: 0.10 | LR: 0.000101 | Avg Reward (Last 20): 768.0
# [BONUS] Step 1360000 | Eps: 0.09 | LR: 0.000099 | Avg Reward (Last 20): 922.0
# [BONUS] Step 1370000 | Eps: 0.09 | LR: 0.000098 | Avg Reward (Last 20): 662.5
# [BONUS] Step 1380000 | Eps: 0.08 | LR: 0.000096 | Avg Reward (Last 20): 829.0
# [BONUS] Step 1390000 | Eps: 0.07 | LR: 0.000095 | Avg Reward (Last 20): 748.0
# [BONUS] Step 1400000 | Eps: 0.07 | LR: 0.000093 | Avg Reward (Last 20): 778.5
# [BONUS] Step 1410000 | Eps: 0.06 | LR: 0.000092 | Avg Reward (Last 20): 752.5
# [BONUS] Step 1420000 | Eps: 0.05 | LR: 0.000091 | Avg Reward (Last 20): 749.5
# [BONUS] Step 1430000 | Eps: 0.05 | LR: 0.000089 | Avg Reward (Last 20): 752.0
# [BONUS] Step 1440000 | Eps: 0.04 | LR: 0.000088 | Avg Reward (Last 20): 757.0
# [BONUS] Step 1450000 | Eps: 0.03 | LR: 0.000086 | Avg Reward (Last 20): 897.0
# [BONUS] Step 1460000 | Eps: 0.03 | LR: 0.000085 | Avg Reward (Last 20): 837.5
# [BONUS] Step 1470000 | Eps: 0.02 | LR: 0.000083 | Avg Reward (Last 20): 951.0
# [BONUS] Step 1480000 | Eps: 0.02 | LR: 0.000082 | Avg Reward (Last 20): 832.5
# [BONUS] Step 1490000 | Eps: 0.02 | LR: 0.000080 | Avg Reward (Last 20): 839.5
# [BONUS] Step 1500000 | Eps: 0.02 | LR: 0.000079 | Avg Reward (Last 20): 839.5
# [BONUS] Step 1510000 | Eps: 0.02 | LR: 0.000077 | Avg Reward (Last 20): 855.0
# [BONUS] Step 1520000 | Eps: 0.02 | LR: 0.000076 | Avg Reward (Last 20): 1047.0
# [BONUS] New best checkpoint saved at step 1520000 with avg reward 1047.0
# [BONUS] Step 1530000 | Eps: 0.02 | LR: 0.000074 | Avg Reward (Last 20): 1041.5
# [BONUS] Step 1540000 | Eps: 0.02 | LR: 0.000073 | Avg Reward (Last 20): 1082.5
# [BONUS] New best checkpoint saved at step 1540000 with avg reward 1082.5
# [BONUS] Step 1550000 | Eps: 0.02 | LR: 0.000071 | Avg Reward (Last 20): 1065.0
# [BONUS] Step 1560000 | Eps: 0.02 | LR: 0.000070 | Avg Reward (Last 20): 1034.5
# [BONUS] Step 1570000 | Eps: 0.02 | LR: 0.000068 | Avg Reward (Last 20): 1101.5
# [BONUS] New best checkpoint saved at step 1570000 with avg reward 1101.5
# [BONUS] Step 1580000 | Eps: 0.02 | LR: 0.000067 | Avg Reward (Last 20): 1047.0
# [BONUS] Step 1590000 | Eps: 0.02 | LR: 0.000065 | Avg Reward (Last 20): 901.0
# [BONUS] Step 1600000 | Eps: 0.02 | LR: 0.000064 | Avg Reward (Last 20): 1133.0
# [BONUS] New best checkpoint saved at step 1600000 with avg reward 1133.0
# [BONUS] Step 1610000 | Eps: 0.02 | LR: 0.000063 | Avg Reward (Last 20): 966.5
# [BONUS] Step 1620000 | Eps: 0.02 | LR: 0.000061 | Avg Reward (Last 20): 1093.0
# [BONUS] Step 1630000 | Eps: 0.02 | LR: 0.000060 | Avg Reward (Last 20): 1067.0
# [BONUS] Step 1640000 | Eps: 0.02 | LR: 0.000058 | Avg Reward (Last 20): 941.5
# [BONUS] Step 1650000 | Eps: 0.02 | LR: 0.000057 | Avg Reward (Last 20): 1041.0
# [BONUS] Step 1660000 | Eps: 0.02 | LR: 0.000055 | Avg Reward (Last 20): 1082.0
# [BONUS] Step 1670000 | Eps: 0.02 | LR: 0.000054 | Avg Reward (Last 20): 1052.0
# [BONUS] Step 1680000 | Eps: 0.02 | LR: 0.000052 | Avg Reward (Last 20): 1134.0
# [BONUS] New best checkpoint saved at step 1680000 with avg reward 1134.0
# [BONUS] Step 1690000 | Eps: 0.02 | LR: 0.000051 | Avg Reward (Last 20): 1291.0
# [BONUS] New best checkpoint saved at step 1690000 with avg reward 1291.0
# [BONUS] Step 1700000 | Eps: 0.02 | LR: 0.000049 | Avg Reward (Last 20): 1062.5
# [BONUS] Step 1710000 | Eps: 0.02 | LR: 0.000048 | Avg Reward (Last 20): 1148.0
# [BONUS] Step 1720000 | Eps: 0.02 | LR: 0.000046 | Avg Reward (Last 20): 1049.0
# [BONUS] Step 1730000 | Eps: 0.02 | LR: 0.000045 | Avg Reward (Last 20): 861.5
# [BONUS] Step 1740000 | Eps: 0.02 | LR: 0.000043 | Avg Reward (Last 20): 1147.0
# [BONUS] Step 1750000 | Eps: 0.02 | LR: 0.000042 | Avg Reward (Last 20): 1253.0
# [BONUS] Step 1760000 | Eps: 0.02 | LR: 0.000040 | Avg Reward (Last 20): 1132.5
# [BONUS] Step 1770000 | Eps: 0.02 | LR: 0.000039 | Avg Reward (Last 20): 1120.0
# [BONUS] Step 1780000 | Eps: 0.02 | LR: 0.000037 | Avg Reward (Last 20): 1286.5
# [BONUS] Step 1790000 | Eps: 0.02 | LR: 0.000036 | Avg Reward (Last 20): 1325.5
# [BONUS] New best checkpoint saved at step 1790000 with avg reward 1325.5
# [BONUS] Step 1800000 | Eps: 0.02 | LR: 0.000034 | Avg Reward (Last 20): 1068.5
# [BONUS] Step 1810000 | Eps: 0.02 | LR: 0.000033 | Avg Reward (Last 20): 1282.0
# [BONUS] Step 1820000 | Eps: 0.02 | LR: 0.000032 | Avg Reward (Last 20): 1297.5
# [BONUS] Step 1830000 | Eps: 0.02 | LR: 0.000030 | Avg Reward (Last 20): 1265.0
# [BONUS] Step 1840000 | Eps: 0.02 | LR: 0.000029 | Avg Reward (Last 20): 1203.5
# [BONUS] Step 1850000 | Eps: 0.02 | LR: 0.000027 | Avg Reward (Last 20): 1118.0
# [BONUS] Step 1860000 | Eps: 0.02 | LR: 0.000026 | Avg Reward (Last 20): 1021.0
# [BONUS] Step 1870000 | Eps: 0.02 | LR: 0.000024 | Avg Reward (Last 20): 1220.0
# [BONUS] Step 1880000 | Eps: 0.02 | LR: 0.000023 | Avg Reward (Last 20): 1060.0
# [BONUS] Step 1890000 | Eps: 0.02 | LR: 0.000021 | Avg Reward (Last 20): 1275.5
# [BONUS] Step 1900000 | Eps: 0.02 | LR: 0.000020 | Avg Reward (Last 20): 916.5
# [BONUS] Step 1910000 | Eps: 0.02 | LR: 0.000018 | Avg Reward (Last 20): 1107.5
# [BONUS] Step 1920000 | Eps: 0.02 | LR: 0.000017 | Avg Reward (Last 20): 1065.0
# [BONUS] Step 1930000 | Eps: 0.02 | LR: 0.000015 | Avg Reward (Last 20): 952.5
# [BONUS] Step 1940000 | Eps: 0.02 | LR: 0.000014 | Avg Reward (Last 20): 954.5
# [BONUS] Step 1950000 | Eps: 0.02 | LR: 0.000012 | Avg Reward (Last 20): 1004.5
# [BONUS] Step 1960000 | Eps: 0.02 | LR: 0.000011 | Avg Reward (Last 20): 1718.0
# [BONUS] New best checkpoint saved at step 1960000 with avg reward 1718.0
# [BONUS] Step 1970000 | Eps: 0.02 | LR: 0.000009 | Avg Reward (Last 20): 1434.5
# [BONUS] Step 1980000 | Eps: 0.02 | LR: 0.000008 | Avg Reward (Last 20): 1597.5
# [BONUS] Step 1990000 | Eps: 0.02 | LR: 0.000006 | Avg Reward (Last 20): 1487.5
# [BONUS] Step 2000000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1538.5
# [BONUS] Step 2010000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1999.0
# [BONUS] New best checkpoint saved at step 2010000 with avg reward 1999.0
# [BONUS] Step 2020000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1436.5
# [BONUS] Step 2030000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1608.5
# [BONUS] Step 2040000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1958.5
# [BONUS] Step 2050000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1893.5
# [BONUS] Step 2060000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 2299.5
# [BONUS] New best checkpoint saved at step 2060000 with avg reward 2299.5
# [BONUS] Step 2070000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1962.0
# [BONUS] Step 2080000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 2253.0
# [BONUS] Step 2090000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1863.5
# [BONUS] Step 2100000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1322.5
# [BONUS] Step 2110000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1037.0
# [BONUS] Step 2120000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1193.5
# [BONUS] Step 2130000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 858.0
# [BONUS] Step 2140000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1157.0
# [BONUS] Step 2150000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 964.5
# [BONUS] Step 2160000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1049.5
# [BONUS] Step 2170000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1828.5
# [BONUS] Step 2180000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1994.5
# [BONUS] Step 2190000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1682.0
# [BONUS] Step 2200000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1075.5
# [BONUS] Step 2210000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1188.5
# [BONUS] Step 2220000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1551.0
# [BONUS] Step 2230000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1122.5
# [BONUS] Step 2240000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 888.0
# [BONUS] Step 2250000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 997.5
# [BONUS] Step 2260000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1174.0
# [BONUS] Step 2270000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1213.0
# [BONUS] Step 2280000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1257.0
# [BONUS] Step 2290000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1125.0
# [BONUS] Step 2300000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1040.5
# [BONUS] Step 2310000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1037.0
# [BONUS] Step 2320000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1062.0
# [BONUS] Step 2330000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1294.0
# [BONUS] Step 2340000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 863.5
# [BONUS] Step 2350000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 879.5
# [BONUS] Step 2360000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1069.5
# [BONUS] Step 2370000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1222.5
# [BONUS] Step 2380000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1154.0
# [BONUS] Step 2390000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1336.0
# [BONUS] Step 2400000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 937.0
# [BONUS] Step 2410000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1312.0
# [BONUS] Step 2420000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1157.5
# [BONUS] Step 2430000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1411.5
# [BONUS] Step 2440000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1265.0
# [BONUS] Step 2450000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1273.0
# [BONUS] Step 2460000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1070.0
# [BONUS] Step 2470000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1314.5
# [BONUS] Step 2480000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 1565.0
# [BONUS] Step 2490000 | Eps: 0.02 | LR: 0.000005 | Avg Reward (Last 20): 964.5
# [BONUS] Training complete. Time: 2499999s
# [BONUS] Latest checkpoint: pacman_bonus_checkpoint.pth
# [BONUS] Best checkpoint:   pacman_bonus_best.pth

# %%
# --- BONUS EVALUATION + VIDEO ---
bonus_video_path = "./pacman_bonus_video"
bonus_eval_env = make_lite_env(BONUS_ENV_ID, render_mode="rgb_array", is_eval=True)
bonus_eval_env = RecordVideo(
    bonus_eval_env,
    video_folder=bonus_video_path,
    name_prefix="bonus-pacman",
    episode_trigger=lambda x: True,
)

if os.path.exists(BONUS_BEST_PATH):
    best_checkpoint = torch.load(BONUS_BEST_PATH, map_location=DEVICE, weights_only=False)
    bonus_q_net.load_state_dict(best_checkpoint["model_state_dict"])
    print(
        f"Loaded BONUS best model from step {best_checkpoint['step']} "
        f"with avg reward {best_checkpoint['avg_reward']:.1f}"
    )
else:
    print("BONUS best checkpoint not found. Evaluating current in-memory bonus model.")

obs, _ = bonus_eval_env.reset()
done = False
bonus_total_eval_score = 0

while not done:
    with torch.no_grad():
        state_t = torch.FloatTensor(np.array([obs])).to(DEVICE)
        action = bonus_q_net(state_t).argmax(dim=1).item()

    obs, reward, terminated, truncated, _ = bonus_eval_env.step(action)
    bonus_total_eval_score += reward
    done = terminated or truncated

bonus_eval_env.close()

print("--- BONUS Evaluation Complete ---")
print(f"BONUS Final Game Score: {bonus_total_eval_score}")
if bonus_total_eval_score >= 1500:
    print("Eligible score threshold met for bonus consideration (>=1500).")
else:
    print("Bonus threshold not met yet (need >=1500).")

# Save final evaluated bonus model snapshot
bonus_final_path = "pacman_bonus_final.pth"
torch.save(
    {
        "model_state_dict": bonus_q_net.state_dict(),
        "score": bonus_total_eval_score,
    },
    bonus_final_path,
)
print(f"BONUS final model saved to {bonus_final_path}")

render_mp4_video(bonus_video_path)

if "bonus_history_rewards" in globals() and "bonus_history_loss" in globals() and len(bonus_history_rewards) > 0:
    plot_metrics(bonus_history_rewards, bonus_history_loss)
# Out:
# Loaded BONUS best model from step 2060000 with avg reward 2299.5
# --- BONUS Evaluation Complete ---
# BONUS Final Game Score: 3800.0
# Eligible score threshold met for bonus consideration (>=1500).
# BONUS final model saved to pacman_bonus_final.pth
#     <video width="600" height="400" controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>
